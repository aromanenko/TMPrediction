# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.preprocessing import OrdinalEncoder
from itertools import product
from ipywidgets import IntProgress
from IPython.display import display

pd.options.display.max_columns = 50
pd.options.mode.chained_assignment = None
# %matplotlib inline

# %%
def log_progress(sequence, every=10):

    progress = IntProgress(min=0, max=len(sequence), value=0)
    display(progress)
    
    for index, record in enumerate(sequence):
        if index % every == 0:
            progress.value = index
        yield record
        

def fix_time(df):
    time = []
    date_fx = []
    months = {"Jan": 1, "Feb": 2, "Mar": 3,
              "Apr": 4, "May": 5, "Jun": 6,
              "Jul": 7, "Aug": 8, "Sep": 9,
              "Oct": 10, "Nov": 11, "Dec": 12
             }
    for date in df["date"]:
        mas = date.split()
        date_fx.append(datetime.date(int(mas[2][:-1]), months[mas[1]], int(mas[0])))
        podmas = mas[-1].split(":")
        time.append(datetime.time(int(podmas[0]), int(podmas[1]), 0))
    df["time"] = time
    df["date"] = date_fx
    
    
def fix_names1(players):
    ## Progress bar
    progress = IntProgress(min=0, max=len(players), value=0)
    display(progress)
    
    arr = []
    for i, x in enumerate(players['name']):
        surname = ''
        tmp = x.split(' ')
        if len(tmp) > 1:
            surname = tmp[-1]
            name = tmp[0][0] + '.'
            arr.append(surname + " " + name)
        else:
            arr.append(np.nan)
        
        ## Progress fill
        if (i % 10 == 0):
            progress.value = i
        
    players['name'] = arr
    
def fix_names2(players):
    ## Progress bar
    progress = IntProgress(min=0, max=len(players), value=0)
    display(progress)
    arr = []
    for i, x in enumerate(players['name']):
        surname = ''
        tmp = x.split(' ')
        if len(tmp) > 1:
            surname = " ".join(tmp[1:])
            name = tmp[0][0] + '.'
            arr.append(surname + " " + name)
        else:
            arr.append(np.nan)
            
        ## Progress fill
        if (i % 10 == 0):
            progress.value = i
    players['name'] = arr


def add_stats(df, players, is_fst_time=1):
    names = ['p1_height', 'p1_birth', 'p1_hand', 'p1_nation']
    progress = IntProgress(min=0, max=len(df), value=0)
    display(progress)
    if is_fst_time:
        for name in names:
            df[name] = [np.nan for x in range(len(df))]
        for name in names:
            df[name.replace('1', '2')] = [np.nan for x in range(len(df))]
    arr1_player1 = []
    arr1_player2 = []
    arr2_player1 = []
    arr2_player2 = []
    arr3_player1 = []
    arr3_player2 = []
    arr4_player1 = []
    arr4_player2 = []
    for i in range(len(df)):
        try:
            player1 = players[df['player1'][i]:].head(1)
            arr1_player1.append(player1['height'][0])
            arr2_player1.append(player1['birth_date'][0])
            arr4_player1.append(player1['hand'][0])
            arr3_player1.append(player1['nationality'][0])
        except Exception:
            arr1_player1.append(df['p1_height'][i])
            arr2_player1.append(df['p1_birth'][i])
            arr4_player1.append(df['p1_hand'][i])
            arr3_player1.append(df['p1_nation'][i])
            
        try:
            player2 = players[df['player2'][i]:].head(1)
            arr1_player2.append(player2['height'][0])
            arr2_player2.append(player2['birth_date'][0])
            arr4_player2.append(player2['hand'][0])
            arr3_player2.append(player2['nationality'][0])
        except Exception:
            arr1_player2.append(df['p2_height'][i])
            arr2_player2.append(df['p2_birth'][i])
            arr4_player2.append(df['p2_hand'][i])
            arr3_player2.append(df['p2_nation'][i])
            
        ## Progress fill
        if (i % 10 == 0):
            progress.value = i
    
    df['p1_height'] = arr1_player1
    df['p2_height'] = arr1_player2
    df['p1_birth'] = arr2_player1
    df['p2_birth'] = arr2_player2
    df['p1_nation'] = arr3_player1
    df['p2_nation'] = arr3_player2
    df['p1_hand'] = arr4_player1
    df['p2_hand'] = arr4_player2

    
def fix_age(df, player_num):
    time = []
    date_fx = []
    months = {"Jan": 1, "Feb": 2, "Mar": 3,
              "Apr": 4, "May": 5, "Jun": 6,
              "Jul": 7, "Aug": 8, "Sep": 9,
              "Oct": 10, "Nov": 11, "Dec": 12
             }
    for date in df["p{0}_birth".format(str(player_num))]:
        if type(date) != float and not pd.isnull(date):
            mas = date.split()
            date_fx.append(datetime.date(int(mas[-1]), months[mas[1]], int(mas[0])))
        else:
            date_fx.append(np.nan)
    df["p{0}_birth".format(str(player_num))] = date_fx

def invert_dataframe(df):    
    stats = ['p1_height', 'p1_birth', 'p1_nation', 'p1_hand', 'p1_points', 'p1_rank']
    for x in df.keys():
        if ('player1' in x or x == 'k1') and x != 'player1_win':
            name2 = x[:-1] + '2'
            tmp = df[x].copy()
            df[x]= df[name2]
            df[name2] = tmp
            
    for x in df.keys():
        if x in stats or 'k1_' in x:
            name2 = x.replace('1', '2', 1)
            tmp = df[x].copy()
            df[x]= df[name2]
            df[name2] = tmp
            
            
    for i in range(len(df)): ## CAN BE IMPROVED
        if df['player1_win'][i] == 1:
            df['player1_win'][i] = 0
        else:
            df['player1_win'][i] = 1
        
    

def create_aces_per_game(df):
    df['total_score_match_player1'] = df['score_set1_player1'].fillna(0)
    df['total_score_match_player2'] = df['score_set1_player2'].fillna(0)
    for x in range(2, 6):
        df['total_score_match_player1'] += df['score_set{0}_player1'.format(x)].fillna(0)
        df['total_score_match_player2'] += df['score_set{0}_player2'.format(x)].fillna(0)
    df['aces_per_game_player1'] = df['aces_match_player1'] / df['srv_games_player1']
    df['aces_per_game_player2'] = df['aces_match_player2'] / df['srv_games_player2']
    
def create_double_faults_per_game(df):
    df['df_per_game_player1'] = df['double_faults_match_player1'] / df['srv_games_player1']
    df['df_per_game_player2'] = df['double_faults_match_player2'] / df['srv_games_player2']
    
def create_feature_WSP(df):
    ## overall_winning_serve
    W1SP_p1 = df['first_serve_points_prc_match_common_player1']
    W2SP_p1 = df['second_serve_points_prc_match_common_player1']
    FS_p1 = df['first_serve_prc_match_common_player1']
    W1SP_p2 = df['first_serve_points_prc_match_common_player2']
    W2SP_p2 = df['second_serve_points_prc_match_common_player2']
    FS_p2 = df['first_serve_prc_match_common_player2']
    df['overall_winning_serve_prc_player1'] = W1SP_p1 * FS_p1 + W2SP_p1 * (1 - FS_p1)
    df['overall_winning_serve_prc_player2'] = W1SP_p2 * FS_p2 + W2SP_p2 * (1 - FS_p2)
    
def create_feature_WRP(df):
    df['winning_on_return_prc_player1'] = df['receiver_points_won_match_player1'] / df['points_won_match_player1']
    df['winning_on_return_prc_player2'] = df['receiver_points_won_match_player2'] / df['points_won_match_player2']

def create_feature_COMPLETE(df):
    df['complete_player1'] = df['winning_on_return_prc_common_player1'] * df['overall_winning_serve_prc_player1']
    df['complete_player2'] = df['winning_on_return_prc_common_player2'] * df['overall_winning_serve_prc_player2']
    
def create_feature_SERVEADV(df):
    df['serve_advantage_player1'] = df['overall_winning_serve_prc_player1'] - df['winning_on_return_prc_common_player2']
    df['serve_advantage_player2'] = df['overall_winning_serve_prc_player2'] - df['winning_on_return_prc_common_player1']
    
def create_diff_features(df):
    arr = ['first_serve_prc_match_common_player1', 'first_serve_points_prc_match_common_player1',
      'second_serve_points_prc_match_common_player1', 'winning_on_return_prc_common_player1',
      'aces_per_game_common_player1', 'df_per_game_common_player1', 'break_points_prc_match_common_player1',
          'serve_advantage_player1', 'complete_player1', 'winning_on_return_prc_player1', 'overall_winning_serve_prc_player1']
    for stat in arr:
        df[stat.replace('player1', '') + '_dif'] = df[stat] - df[stat.replace('1', '2')]
    

## FINISHED
def create_retirement_stat(df):
    players = list(set(df['player1']) or set(df['player2']))
    arr1 = [0 for x in range(len(df))]
    arr2 = [0 for x in range(len(df))]
    ## Progress bar
    progress = IntProgress(min=0, max=len(players), value=0)
    display(progress)
    for k, player in enumerate(players):
        subset = df[(df['player1'] == player) | (df['player2'] == player)]
        for i in range(1, len(subset)):
            if len(subset) > 1:
                player1 = list(subset['player1'])
                status = list(subset['status'])
                player2 = list(subset['player2'])
                fl = list(subset['player1_win'])
                if (player1[i] == player):    
                    if ((status[i - 1] == 'Retired') and (player1[i - 1] == player) and (fl[i - 1] == 0)):
                        arr1[subset.index[i]] = 1
                    if ((status[i - 1] == 'Retired') and (player2[i - 1] == player) and (fl[i - 1] == 1)):
                        arr1[subset.index[i]] = 1
                else:
                    if ((status[i - 1] == 'Retired') and (player1[i - 1] == player) and (fl[i - 1] == 0)):
                        arr2[subset.index[i]] = 1
                    if ((status[i - 1] == 'Retired') and (player2[i - 1] == player) and (fl[i - 1] == 1)):
                        arr2[subset.index[i]] = 1
                        
        ## Progress fill
        if (k % 10 == 0):
            progress.value = k
    df['1st_match_since_retirement_player1'] = arr1
    df['1st_match_since_retirement_player2'] = arr2
    
## FINISHED (df - DataFrame, stats - array of stats, include only player1 stats)
def create_common_stats(df, stats):
    for stat in stats:
        print("CREATING STAT {0}_common...".format(stat.replace('player1', '')))
        arr1 = [np.nan for x in range(len(df))]
        arr2 = [np.nan for x in range(len(df))]
        stat_p1 = stat
        stat_p2 = stat.replace('1', '2')
        df_dropped = df[(df[stat_p1] == df[stat_p1])] ## df after dropping Nan
        
        progress = IntProgress(min=0, max=len(df_dropped), value=0)
        display(progress)
        
        for i in range(len(df_dropped)):
            df_tmp = df_dropped[df_dropped['date'] <= list(df_dropped['date'])[i]]
            players_p1 = set(df_tmp[df_tmp['player1'] == (list(df_tmp['player1'])[i])]['player2']) | set(df_tmp[df_tmp['player2'] == (list(df_tmp['player1'])[i])]['player1'])
            players_p2 = set(df_tmp[df_tmp['player1'] == (list(df_tmp['player2'])[i])]['player2']) | set(df_tmp[df_tmp['player2'] == (list(df_tmp['player2'])[i])]['player1'])
            common_players = players_p1 & players_p2 ## common opponents
            wrp1 = 0
            wrp1_cnt = 0
            wrp2 = 0
            wrp2_cnt = 0
            for p in common_players:
                wrp1 += df_tmp[(df_tmp['player1'] == list(df_tmp['player1'])[i]) & (df_tmp['player2'] == p)][stat_p1].sum()
                wrp1_cnt += len(df_tmp[(df_tmp['player1'] == list(df_tmp['player1'])[i]) & (df_tmp['player2'] == p)])
                wrp1 += df_tmp[(df_tmp['player2'] == list(df_tmp['player1'])[i]) & (df_tmp['player1'] == p)][stat_p2].sum()
                wrp1_cnt += len(df_tmp[(df_tmp['player2'] == list(df_tmp['player1'])[i]) & (df_tmp['player1'] == p)])

                wrp2 += df_tmp[(df_tmp['player1'] == list(df_tmp['player2'])[i]) & (df_tmp['player2'] == p)][stat_p1].sum()
                wrp2_cnt += len(df_tmp[(df_tmp['player1'] == list(df_tmp['player2'])[i]) & (df_tmp['player2'] == p)])
                wrp2 += df_tmp[(df_tmp['player2'] == list(df_tmp['player2'])[i]) & (df_tmp['player1'] == p)][stat_p2].sum()
                wrp2_cnt += len(df_tmp[(df_tmp['player2'] == list(df_tmp['player2'])[i]) & (df_tmp['player1'] == p)])
            if (wrp1_cnt != 0):
                wrp1 /= wrp1_cnt
                wrp2 /= wrp2_cnt
                arr1[df_tmp['player1'].index[i]] = wrp1
                arr2[df_tmp['player2'].index[i]] = wrp2
            
            ## Progress fill
            if (i % 10 == 0):
                progress.value = i

        print("STAT {0}common CREATED".format(stat.replace('player1', '')))
        df[stat_p1.replace('player1', '') + 'common_player1'] = arr1
        df[stat_p2.replace('player2', '') + 'common_player2'] = arr2
    
def percentile(n):
    '''Calculate n - percentile of data'''
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'pctl%s' % n
    return percentile_

def lagged_features(df
    ,target_var = ['aces_match_player1']
    , lags = [1]
    , windows = [28]
    , aggregation_methods = {'mean', 'median', percentile(10), percentile(90)}
    , surface_type_filter = [1, -1]):
    ## with no surface type filter
    players = ['player1', 'player2']
    df = df.reset_index()
    for p in players:
        if -1 in surface_type_filter:
            for l, w, t in product(lags, windows, target_var):
                t1 = t
                if p == 'player2':
                    t1 = t1.replace("player1", "player2")
                lf_df = df.set_index(['player1', 'player2', 'date'])[t1].\
                         groupby(level=p).apply(lambda x: x.rolling(window=w, min_periods = 1).agg(aggregation_methods).shift(l))
                t1 = t1.replace("player1", "").replace("player2", "")
                new_names = {x: "{0}_lag_{1}_{2}_{3}_{4}".
                              format(p.replace("player", "p"), l, t1, x, w) for x in lf_df.columns}

                df = df.merge(lf_df.reset_index().rename(columns = new_names),
                    how='left', on =['player1', 'player2', 'date'] )
        ## with surface type filter
        if 1 in surface_type_filter:
            for l, w, t in product(lags, windows, target_var):
                t1 = t
                if p == 'player2':
                    t1 = t1.replace("player1", "player2")
                df.head()
                lf_df = df.set_index(['player1', 'player2', 'date', 'Surface'])[t1].\
                         groupby(level=[p, 'Surface']).apply(lambda x: x.rolling(window=w, min_periods = 1).agg(aggregation_methods).shift(l))
                t1 = t1.replace("player1", "").replace("player2", "")
                new_names = {x: "{0}_filter_lag_{1}_{2}_{3}_{4}".
                              format(p.replace("player", "p"), l, t1, x, w) for x in lf_df.columns}

                df = df.merge(lf_df.reset_index().rename(columns = new_names),
                    how='left', on =['player1', 'player2', 'date', 'Surface'])
    return df

# %%
## How to fill missings in k1/k2? ---- Here as a rule, high coef on player1 and no coef on player2
def drop_n_fill_trash(df):
    for k in df.keys():
        if 'k2' in k:
            for i in range(len(df)):
                if '%' in str(df[k][i]):
                    if float(df[k.replace('k2', 'k1')][i]) < 11:
                        df[k][i] = 1.01
                    else:
                        df[k][i] = np.nan
    
    set_ = set()
    for k in df.keys():
        if 'k2' in k:
            for i in range(len(df)):
                if '-' in str(df[k][i]):
                    set_.add(i)
    return set_

def combine(df, df_):
    progress = IntProgress(min=0, max=len(df_), value=0)
    display(progress)

    for i in range(len(df_)):

        player1 = df_['player1'][i]
        player2 = df_['player2'][i]
        date = np.datetime64(df_['date'][i])
        match = df[(df['player1'] == player1) & (df['player2'] == player2) & ((df['date'] == date) | (df['date'] == date + 1) | (df['date'] == date - 1))]

        if len(match) == 1:
            for k in list(df.keys())[3:]: ## k1_1Xbet, ....
                df_.loc[i, k] = float(match[k])

        match = df[(df['player1'] == player2) & (df['player2'] == player1) & ((df['date'] == date) | (df['date'] == date + 1) | (df['date'] == date - 1))]

        if len(match) == 1:
            for k in list(df.keys())[3:]: ## k1_1Xbet, ....
                if 'k1' in k:
                    df_.loc[i, k.replace('k1', 'k2')] = float(match[k])
                else:
                    df_.loc[i, k.replace('k2', 'k1')] = float(match[k])

        if (i % 10 == 0):
            progress.value = i

            
def fix_letters(df_):
    progress = IntProgress(min=0, max=len(df_), value=0)
    display(progress)
    bug_surnames = {'Hüsler M.': 'Huesler M.', 'Mcdonald M.': 'McDonald M.',
                    'del Potro J.': 'Del Potro J.', 'López-Pérez E.': 'Lopez-Perez E.',
                   'Di Wu.': 'Wu D.', 'Yen-Hsun Lu.': 'Lu Y.H.', 'Mcgee J.': 'McGee J.',
                   'Zhe Li.': 'Li Z.', 'Wolf J.J.': 'Wolf J.', 'Bautista Agut R.': 'Bautista-Agut R.',
                   'Ramos-Viñolas A.': 'Ramos A.', 'Carreño Busta P.': 'Carreno-Busta P.', 'Struff J.': 'Struff J-L.',
                   'Tsonga J.': 'Tsonga J-W.', 'de Minaur A.': 'De Minaur A.', 'Andújar P.': 'Andujar-Alba P.',
                    'Dutra Silva R.': 'Dutra Da Silva D.', 'Smith J.': 'Smith J. P.', 'Estrella Burgos V.': 'Estrella V.',
                    'Popyrin A.': 'Popyrin Al.', 'Londero J.': 'Londero J. I.', 'Harris L.': 'Harris G.',
                    'de Bakker T.': 'De Bakker T.', 'Kwon S.': 'Kwon Soonwoo', 'Galán D.': 'Galan Riveros D. E.',
                    'Lee D.': 'Lee D. H.', 'Muñoz de la Nava D.': 'Munoz-De La Nava D.', 'Ojeda Lara R.': 'Ojeda L. R.',
                    'Kuznetsov A.': 'Kuznetsov Al.', 'Lindell C.': 'Lindell Ch.', 'Vilella Martínez M.': 'Vilella M. M.',
                    'Kwiatkowski T.': 'Kwiatkowski T. S.', 'Moroni G.': 'Moroni M.',
                    'Huta Galung J.': 'Huta-Galung J.', 'Mukund S.': 'Mukund S. K.', 'Ramirez Hidalgo R.': 'Ramirez-H.R.',
                    'Tyurnev E.': 'Tiurnev E.', 'Yecong He.': 'He Y.', 'Statham R.': 'Statham J. R.',
                   'Rigele Te.': 'Te R.', 'Prashanth N.': 'Prashanth V.', 'Yibing W.': 'Wu Y.',
                    'Varillas J.': 'Varillas J. P.', 'Ficovich J.': 'Ficovich J. P.', 'Lipovšek Puches T.': 'Lipovsek P. T.',
                    'Tatlot J.': 'Tatlot J. S.', 'Sorgi J.': 'Sorgi J. P.', 'Zayed M.': 'Zayed M. S.'}
    letters = {'á': 'a', 'ã': 'a', 'ç': 'c',
           'é': 'e', 'í': 'i', 'ñ': 'n',
           'ó': 'o', 'ö': 'o', 'ú': 'u',
          'ü': 'u', 'ý': 'y', 'ć': 'c',
          'č': 'c', 'ě': 'e', 'ı': 'i',
          'ł': 'l', 'ř': 'r', 'š': 's',
          'ž': 'z'}
    for i in range(len(df_)):
        p1 = df_['player1'][i]
        p2 = df_['player2'][i]
        p2.replace('\n', '') ## лишние \n при парсинге oddsportal
        
        if p1 in bug_surnames:
            p1 = bug_surnames[p1]
            
        if p2 in bug_surnames:
            p2 = bug_surnames[p2]

        for c in range(len(p1)):
            if p1[c].lower() in letters:
                if p1[c].islower():
                    p1 = p1.replace(p1[c], letters[p1[c]])
                else:
                    p1 = p1.replace(p1[c], letters[p1[c].lower()].upper())

        for c in range(len(p2)):
            if p2[c].lower() in letters:
                if p2[c].islower():
                    p2 = p2.replace(p2[c], letters[p2[c]])                    
                else:
                    p2 = p2.replace(p2[c], letters[p2[c].lower()].upper())

        df_['player1'][i] = p1
        df_['player2'][i] = p2
        
        if i % 10 == 0:
            progress.value = i

# %%
## read data
print("LOADING DATA...")
df = pd.read_pickle('matches.pkl') 
players1 = pd.read_pickle('players.pkl')
players2 = pd.read_pickle('players.pkl')
print("DATA LOADED")


## fixing time
fix_time(df)

## fix players' names for transporting stats
print("FIXING PLAYERS' NAMES...")
fix_names1(players1)
fix_names2(players2)
players1 = players1.set_index(['name'])
players2 = players2.set_index(['name'])
print("PLAYERS' NAMES FIXED")

## transporting stats players --> dataframe
print("IMPORTING STATIC STATS...")
add_stats(df, players1)
add_stats(df, players2, 0)
print("STATIC STATS IMPORTED")


df_odds = pd.read_pickle('all_odds.pkl')
df_odds = df_odds.reset_index()

df_odds.drop(['k1_Asianodds', 'k2_Asianodds', 'k1_GGBET', 'k2_GGBET', 'k1_William', 'k2_William'], axis=1, inplace=True)

set_ = drop_n_fill_trash(df_odds)
## del trash
for ind in set_:
    df_odds = df_odds.drop(ind)
df_odds = df_odds.set_index('player1').reset_index()

## fix letters in data
fix_letters(df)

## combine coefs and data
combine(df_odds, df)

## create retirement stat
print("CREATING STAT RETIREMENT...")
create_retirement_stat(df)
print("STAT RETIREMENT CREATED")


## converting age to datetime
fix_age(df, 1)
fix_age(df, 2)



## converting some stats to datetime in df for the next steps
df['date'] = pd.to_datetime(df['date'])
df['p1_birth'] = pd.to_datetime(df['p1_birth'])
df['p2_birth'] = pd.to_datetime(df['p2_birth'])

# count prc of winning points on return
create_feature_WRP(df)

## normalize to per_game stats
create_aces_per_game(df)
create_double_faults_per_game(df)


## create stats based on common opponents
print("CREATING STATS BASED ON COMMON OPPONENTS...")
stats = ['first_serve_prc_match_player1', 'first_serve_points_prc_match_player1',
         'second_serve_points_prc_match_player1', 'winning_on_return_prc_player1',
        'aces_per_game_player1', 'df_per_game_player1', 'break_points_prc_match_player1']
create_common_stats(df, stats)
print("STATS BASED ON COMMON OPPONENTS CREATED")


# ## create new features
# create_feature_WSP(df)
# create_feature_COMPLETE(df)
# create_feature_SERVEADV(df)
# # create_diff_features(df)

# # add invert matches
# print("ADDING INVERT MATCHES...")
# df_copy = df.copy()
# invert_dataframe(df_copy)
# df = df.reset_index()
# df = df.set_index(["player1", "player2"])
# df_copy = df_copy.set_index(["player1", "player2"])
# df = df.append(df_copy)
# df = df.reset_index()
# print("INVERT MATCHES ADDED")

# ## drop Nan stats
# df = df.dropna(subset=['p1_height'])
# df = df.dropna(subset=['p2_height'])
# df = df.dropna(subset=['p1_birth'])
# df = df.dropna(subset=['p2_birth'])
# # df = df.dropna(subset=['k1'])
# # df = df.dropna(subset=['k2'])
# df = df.set_index(['date', 'player1', 'player2'])
# df = df.sort_index()

# print(df.shape)
# df.head(3)
# Out:
# LOADING DATA...
# DATA LOADED
# FIXING PLAYERS' NAMES...
# IntProgress(value=0, max=1357)
# IntProgress(value=0, max=1357)
# PLAYERS' NAMES FIXED
# IMPORTING STATIC STATS...
# IntProgress(value=0, max=26030)
# IntProgress(value=0, max=26030)
# STATIC STATS IMPORTED
# IntProgress(value=0, max=26030)
# IntProgress(value=0, max=26030)
# CREATING STAT RETIREMENT...
# IntProgress(value=0, max=1126)
# STAT RETIREMENT CREATED
# CREATING STATS BASED ON COMMON OPPONENTS...
# CREATING STAT first_serve_prc_match__common...
# IntProgress(value=0, max=11388)
# STAT first_serve_prc_match_common CREATED
# CREATING STAT first_serve_points_prc_match__common...
# IntProgress(value=0, max=11388)
# STAT first_serve_points_prc_match_common CREATED
# CREATING STAT second_serve_points_prc_match__common...
# IntProgress(value=0, max=11388)
# STAT second_serve_points_prc_match_common CREATED
# CREATING STAT winning_on_return_prc__common...
# IntProgress(value=0, max=11388)
# STAT winning_on_return_prc_common CREATED
# CREATING STAT aces_per_game__common...
# IntProgress(value=0, max=11594)
# STAT aces_per_game_common CREATED
# CREATING STAT df_per_game__common...
# IntProgress(value=0, max=11347)
# STAT df_per_game_common CREATED
# CREATING STAT break_points_prc_match__common...
# IntProgress(value=0, max=11389)
# STAT break_points_prc_match_common CREATED
# STATS BASED ON COMMON OPPONENTS CREATED

# %%
df.tail(5)
# Out:
#                                                match_url      player1  \
# 26025  https://www.sofascore.com/zverev-djokovic/HXfsnTx  Djokovic N.
# 26026  https://www.sofascore.com/schwartzman-medvedev...  Medvedev D.
# 26027   https://www.sofascore.com/thiem-djokovic/HXfsYzr     Thiem D.
# 26028  https://www.sofascore.com/medvedev-nadal/LOfsevpb  Medvedev D.
# 26029  https://www.sofascore.com/thiem-medvedev/Yzrsevpb  Medvedev D.
#
#               player2 status           Surface       date    k1    k2  \
# 26025       Zverev A.  Ended  Hardcourt indoor 2020-11-20  1.33  3.40
# 26026  Schwartzman D.  Ended  Hardcourt indoor 2020-11-20  1.28  3.75
# 26027     Djokovic N.  Ended  Hardcourt indoor 2020-11-21  2.37  1.57
# 26028        Nadal R.  Ended  Hardcourt indoor 2020-11-21  1.72  2.10
# 26029        Thiem D.  Ended  Hardcourt indoor 2020-11-22  1.66  2.20
#
#        player1_win       round match_duration_mnt Location  duration_set1  \
# 26025            1           A                 96  London            33.0
# 26026            1           A                 74  London            37.0
# 26027            1  Semifinals                174  London            51.0
# 26028            1  Semifinals                155  London            46.0
# 26029            1       Final                162  London            48.0
#
#        duration_set2  duration_set3  duration_set4  duration_set5  \
# 26025           63.0            NaN            NaN            NaN
# 26026           37.0            NaN            NaN            NaN
# 26027           66.0           56.0            NaN            NaN
# 26028           56.0           52.0            NaN            NaN
# 26029           61.0           52.0            NaN            NaN
#
#        aces_match_player1  aces_match_player2  double_faults_match_player1  \
# 26025                 3.0                12.0                          3.0
# 26026                 4.0                 1.0                          1.0
# 26027                12.0                 4.0                          5.0
# 26028                13.0                 3.0                          3.0
# 26029                12.0                 7.0                          3.0
#
#        double_faults_match_player2  first_serve_prc_match_player1  \
# 26025                          6.0                       0.666667
# 26026                          0.0                       0.740741
# 26027                          0.0                       0.683333
# 26028                          3.0                       0.695122
# 26029                          1.0                       0.754545
#
#        first_serve_prc_match_player2  first_serve_cnt_match_player1  \
# 26025                       0.754386                           52.0
# 26026                       0.683333                           40.0
# 26027                       0.719298                           82.0
# 26028                       0.564103                           57.0
# 26029                       0.863248                           83.0
#
#        first_serve_cnt_match_player2  ...  k2_Coolbet  \
# 26025                           43.0  ...        3.78
# 26026                           41.0  ...        3.87
# 26027                           82.0  ...        1.62
# 26028                           66.0  ...        2.05
# 26029                          101.0  ...        2.40
#
#        1st_match_since_retirement_player1  1st_match_since_retirement_player2  \
# 26025                                   0                                   0
# 26026                                   0                                   0
# 26027                                   0                                   0
# 26028                                   0                                   0
# 26029                                   0                                   0
#
#        winning_on_return_prc_player1  winning_on_return_prc_player2  \
# 26025                       0.228571                       0.369231
# 26026                       0.384615                       0.285714
# 26027                       0.277311                       0.295652
# 26028                       0.466667                       0.276596
# 26029                       0.347826                       0.312500
#
#        total_score_match_player1  total_score_match_player2  \
# 26025                       13.0                        9.0
# 26026                       12.0                        6.0
# 26027                       20.0                       18.0
# 26028                       16.0                       15.0
# 26029                       17.0                       16.0
#
#        aces_per_game_player1  aces_per_game_player2  df_per_game_player1  \
# 26025               0.300000               1.090909             0.300000
# 26026               0.444444               0.111111             0.111111
# 26027               0.666667               0.222222             0.277778
# 26028               0.812500               0.214286             0.187500
# 26029               0.750000               0.437500             0.187500
#
#        df_per_game_player2  first_serve_prc_match_common_player1  \
# 26025             0.545455                              0.670097
# 26026             0.000000                              0.631415
# 26027             0.000000                              0.641025
# 26028             0.214286                              0.632172
# 26029             0.062500                              0.634686
#
#        first_serve_prc_match_common_player2  \
# 26025                              0.674025
# 26026                              0.660978
# 26027                              0.671611
# 26028                              0.688126
# 26029                              0.640478
#
#        first_serve_points_prc_match_common_player1  \
# 26025                                     0.745601
# 26026                                     0.732125
# 26027                                     0.739388
# 26028                                     0.730370
# 26029                                     0.734239
#
#        first_serve_points_prc_match_common_player2  \
# 26025                                     0.743877
# 26026                                     0.655205
# 26027                                     0.749696
# 26028                                     0.730408
# 26029                                     0.731920
#
#        second_serve_points_prc_match_common_player1  \
# 26025                                      0.561955
# 26026                                      0.524961
# 26027                                      0.531193
# 26028                                      0.526984
# 26029                                      0.522934
#
#        second_serve_points_prc_match_common_player2  \
# 26025                                      0.499086
# 26026                                      0.483393
# 26027                                      0.555633
# 26028                                      0.590901
# 26029                                      0.522412
#
#        winning_on_return_prc_common_player1  \
# 26025                              0.395215
# 26026                              0.364047
# 26027                              0.372535
# 26028                              0.369188
# 26029                              0.368747
#
#        winning_on_return_prc_common_player2  aces_per_game_common_player1  \
# 26025                              0.375479                      0.400395
# 26026                              0.413922                      0.610892
# 26027                              0.393878                      0.486419
# 26028                              0.402100                      0.623172
# 26029                              0.367072                      0.616668
#
#        aces_per_game_common_player2  df_per_game_common_player1  \
# 26025                      0.629809                    0.203788
# 26026                      0.176634                    0.289684
# 26027                      0.422324                    0.227905
# 26028                      0.291201                    0.279904
# 26029                      0.465540                    0.285989
#
#        df_per_game_common_player2  break_points_prc_match_common_player1  \
# 26025                    0.319136                               0.467683
# 26026                    0.225532                               0.408969
# 26027                    0.203736                               0.395190
# 26028                    0.159306                               0.416665
# 26029                    0.239209                               0.404553
#
#        break_points_prc_match_common_player2
# 26025                               0.444288
# 26026                               0.433232
# 26027                               0.478712
# 26028                               0.460037
# 26029                               0.397300
#
# [5 rows x 284 columns]

# %%
## temp decision
# df.rename(columns={"first_serve_prc_match_player1_common": "first_serve_prc_match_common_player1",
#                    "first_serve_prc_match_player2_common": "first_serve_prc_match_common_player2",
#                    "first_serve_points_prc_match_player1_common": "first_serve_points_prc_match_common_player1",
#                   "first_serve_points_prc_match_player2_common": "first_serve_points_prc_match_common_player2",
#                    "second_serve_points_prc_match_player1_common": "second_serve_points_prc_match_common_player1",
#                   "second_serve_points_prc_match_player2_common": "second_serve_points_prc_match_common_player2",
#                   "winning_on_return_prc_player1_common": "winning_on_return_prc_common_player1",
#                   "winning_on_return_prc_player2_common": "winning_on_return_prc_common_player2",
#                   "aces_per_game_player1_common": "aces_per_game_common_player1",
#                   "aces_per_game_player2_common": "aces_per_game_common_player2",
#                   "df_per_game_player1_common": "df_per_game_common_player1",
#                   "df_per_game_player2_common": "df_per_game_common_player2",
#                   "break_points_prc_match_player1_common": "break_points_prc_match_common_player1",
#                   "break_points_prc_match_player2_common": "break_points_prc_match_common_player2"}, inplace=True)


## create new features
create_feature_WSP(df)
create_feature_COMPLETE(df)
create_feature_SERVEADV(df)
create_diff_features(df)

## add invert matches
print("ADDING INVERT MATCHES...")
df_copy = df.copy()
invert_dataframe(df_copy)
df = df.reset_index()
df = df.set_index(["player1", "player2"])
df_copy = df_copy.set_index(["player1", "player2"])
df = df.append(df_copy)
df = df.reset_index()
df = df.set_index(['date', 'player1', 'player2'])
df = df.sort_index()
print("INVERT MATCHES ADDED")
print(df.shape)
df.head(3)
# Out:
# ADDING INVERT MATCHES...
# INVERT MATCHES ADDED
# (52060, 299)
#                                      index  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.       NaN
#            Bedene A. Kudryavtsev A.    7.0
#            Brands D. Ferrer D.        14.0
#
#                                                                              match_url  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.     https://www.sofascore.com/becker-wawrinka/YPfsHng
#            Bedene A. Kudryavtsev A.  https://www.sofascore.com/bedene-kudryavtsev/a...
#            Brands D. Ferrer D.         https://www.sofascore.com/brands-ferrer/eNfsgCg
#
#                                       status            Surface  k1  k2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.       Ended  Hardcourt outdoor NaN NaN
#            Bedene A. Kudryavtsev A.  Retired  Hardcourt outdoor NaN NaN
#            Brands D. Ferrer D.         Ended  Hardcourt outdoor NaN NaN
#
#                                      player1_win  round match_duration_mnt  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.               0  (R16)                NaN
#            Bedene A. Kudryavtsev A.            1  (R16)                NaN
#            Brands D. Ferrer D.                 1  (R16)                NaN
#
#                                     Location  duration_set1  duration_set2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.         NaN            NaN            NaN
#            Bedene A. Kudryavtsev A.      NaN            NaN            NaN
#            Brands D. Ferrer D.           NaN            NaN            NaN
#
#                                      duration_set3  duration_set4  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.               NaN            NaN
#            Bedene A. Kudryavtsev A.            NaN            NaN
#            Brands D. Ferrer D.                 NaN            NaN
#
#                                      duration_set5  aces_match_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.               NaN                 NaN
#            Bedene A. Kudryavtsev A.            NaN                 NaN
#            Brands D. Ferrer D.                 NaN                 NaN
#
#                                      aces_match_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                    NaN
#            Bedene A. Kudryavtsev A.                 NaN
#            Brands D. Ferrer D.                      NaN
#
#                                      double_faults_match_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                             NaN
#            Bedene A. Kudryavtsev A.                          NaN
#            Brands D. Ferrer D.                               NaN
#
#                                      double_faults_match_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                             NaN
#            Bedene A. Kudryavtsev A.                          NaN
#            Brands D. Ferrer D.                               NaN
#
#                                      first_serve_prc_match_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                               NaN
#            Bedene A. Kudryavtsev A.                            NaN
#            Brands D. Ferrer D.                                 NaN
#
#                                      first_serve_prc_match_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                               NaN
#            Bedene A. Kudryavtsev A.                            NaN
#            Brands D. Ferrer D.                                 NaN
#
#                                      first_serve_cnt_match_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                               NaN
#            Bedene A. Kudryavtsev A.                            NaN
#            Brands D. Ferrer D.                                 NaN
#
#                                      first_serve_cnt_match_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                               NaN
#            Bedene A. Kudryavtsev A.                            NaN
#            Brands D. Ferrer D.                                 NaN
#
#                                      second_serve_prc_match_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                NaN
#            Bedene A. Kudryavtsev A.                             NaN
#            Brands D. Ferrer D.                                  NaN
#
#                                      second_serve_prc_match_player2  ...  \
# date       player1   player2                                         ...
# 2014-01-01 Becker B. Wawrinka S.                                NaN  ...
#            Bedene A. Kudryavtsev A.                             NaN  ...
#            Brands D. Ferrer D.                                  NaN  ...
#
#                                      winning_on_return_prc_common_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                      NaN
#            Bedene A. Kudryavtsev A.                                   NaN
#            Brands D. Ferrer D.                                        NaN
#
#                                      winning_on_return_prc_common_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                      NaN
#            Bedene A. Kudryavtsev A.                                   NaN
#            Brands D. Ferrer D.                                        NaN
#
#                                      aces_per_game_common_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                              NaN
#            Bedene A. Kudryavtsev A.                           NaN
#            Brands D. Ferrer D.                                NaN
#
#                                      aces_per_game_common_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                              NaN
#            Bedene A. Kudryavtsev A.                           NaN
#            Brands D. Ferrer D.                                NaN
#
#                                      df_per_game_common_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                            NaN
#            Bedene A. Kudryavtsev A.                         NaN
#            Brands D. Ferrer D.                              NaN
#
#                                      df_per_game_common_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                            NaN
#            Bedene A. Kudryavtsev A.                         NaN
#            Brands D. Ferrer D.                              NaN
#
#                                      break_points_prc_match_common_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                       NaN
#            Bedene A. Kudryavtsev A.                                    NaN
#            Brands D. Ferrer D.                                         NaN
#
#                                      break_points_prc_match_common_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                       NaN
#            Bedene A. Kudryavtsev A.                                    NaN
#            Brands D. Ferrer D.                                         NaN
#
#                                      overall_winning_serve_prc_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                   NaN
#            Bedene A. Kudryavtsev A.                                NaN
#            Brands D. Ferrer D.                                     NaN
#
#                                      overall_winning_serve_prc_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                   NaN
#            Bedene A. Kudryavtsev A.                                NaN
#            Brands D. Ferrer D.                                     NaN
#
#                                      complete_player1  complete_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                  NaN               NaN
#            Bedene A. Kudryavtsev A.               NaN               NaN
#            Brands D. Ferrer D.                    NaN               NaN
#
#                                      serve_advantage_player1  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                         NaN
#            Bedene A. Kudryavtsev A.                      NaN
#            Brands D. Ferrer D.                           NaN
#
#                                      serve_advantage_player2  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                         NaN
#            Bedene A. Kudryavtsev A.                      NaN
#            Brands D. Ferrer D.                           NaN
#
#                                      first_serve_prc_match_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                   NaN
#            Bedene A. Kudryavtsev A.                                NaN
#            Brands D. Ferrer D.                                     NaN
#
#                                      first_serve_points_prc_match_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                          NaN
#            Bedene A. Kudryavtsev A.                                       NaN
#            Brands D. Ferrer D.                                            NaN
#
#                                      second_serve_points_prc_match_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                           NaN
#            Bedene A. Kudryavtsev A.                                        NaN
#            Brands D. Ferrer D.                                             NaN
#
#                                      winning_on_return_prc_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                   NaN
#            Bedene A. Kudryavtsev A.                                NaN
#            Brands D. Ferrer D.                                     NaN
#
#                                      aces_per_game_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                           NaN
#            Bedene A. Kudryavtsev A.                        NaN
#            Brands D. Ferrer D.                             NaN
#
#                                      df_per_game_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                         NaN
#            Bedene A. Kudryavtsev A.                      NaN
#            Brands D. Ferrer D.                           NaN
#
#                                      break_points_prc_match_common__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                    NaN
#            Bedene A. Kudryavtsev A.                                 NaN
#            Brands D. Ferrer D.                                      NaN
#
#                                      serve_advantage__dif  complete__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                      NaN            NaN
#            Bedene A. Kudryavtsev A.                   NaN            NaN
#            Brands D. Ferrer D.                        NaN            NaN
#
#                                      winning_on_return_prc__dif  \
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                            NaN
#            Bedene A. Kudryavtsev A.                         NaN
#            Brands D. Ferrer D.                              NaN
#
#                                      overall_winning_serve_prc__dif
# date       player1   player2
# 2014-01-01 Becker B. Wawrinka S.                                NaN
#            Bedene A. Kudryavtsev A.                             NaN
#            Brands D. Ferrer D.                                  NaN
#
# [3 rows x 299 columns]

# %%
df = df.set_index(['date', 'player1', 'player2'])

# %%
plt.figure(figsize=(10, 5))
plt.ylabel("matches")
plt.xlabel("year")
plt.hist(df.index.get_level_values('date'), bins=50);

# %%
df['p1_age'] = (df.index.get_level_values('date') - df['p1_birth']).dt.days / 365
df['p2_age'] = (df.index.get_level_values('date') - df['p2_birth']).dt.days / 365

# %%
df['p1_birthday_today'] = \
    (df['p1_birth'].dt.month == df.index.get_level_values('date').month) & \
    (df['p1_birth'].dt.day == df.index.get_level_values('date').day)

df['p2_birthday_today'] = \
    (df['p2_birth'].dt.month == df.index.get_level_values('date').month) & \
    (df['p2_birth'].dt.day == df.index.get_level_values('date').day)

# %%
df['hour'] = df['time'].map(lambda x: x.hour)

# %%
df['Surface'] = df['Surface'].fillna('N/A')

surface_encoder = OrdinalEncoder()
df['Surface'] = surface_encoder.fit_transform(df['Surface'].values.reshape(-1,1)); ## Clay - 0.0, Grass - 1.0, Hard outdoor - 3.0, Hard court indoor - 2.0

# %%
df['round'] = df['round'].fillna('N/A')

round_encoder = OrdinalEncoder()
df['round'] = round_encoder.fit_transform(df['round'].values.reshape(-1,1));
df.rename(columns={"match_duration_mnt": "match_dur"}, inplace=True)

# %%
df = pd.read_pickle('temp_file.pkl')

# %%
stats = []
for x in df.keys():
    ## if ('match' in x and 'player1' in x) or ('set' in x and 'player1' in x) or ('bp' in x):
    if ('match' in x and 'player1' in x and 'common' not in x and 'score' not in x) or ('bp' in x):
        stats.append(x)
stats.pop(stats.index('1st_match_since_retirement_player1'))
df_new = lagged_features(df, target_var=stats, windows=[7, 28], aggregation_methods=['mean', 'median', percentile(90), percentile(10)])

for i, x in enumerate(df_new['match_dur']):
    if 'after' in str(x):
        df_new.drop(i, axis='index', inplace=True)

df_new = lagged_features(df_new, target_var=['match_dur'], windows=[1, 3, 7], aggregation_methods=['mean', 'median', percentile(90), percentile(10)])
# Out:
# /Users/yasha_ten/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
df_new = lagged_features(df, target_var=['match_dur'], windows=[7], aggregation_methods=['mean', 'median', percentile(90), percentile(10)])

# %%
# df.rename(columns={"player1": "p1", "player2": "p2", "player1_win": "p1_win"}, inplace=True)
df_new.rename(columns={"player1": "p1", "player2": "p2", "player1_win": "p1_win"}, inplace=True)

# %%
df_new = df_new.set_index(["date", "p1", "p2"])
# df = df.set_index(["date", "p1", "p2"])

# %%
df_new.to_pickle('all_features.pkl')

# %%
features_from = '2015-01-01'

cols2keep = set(['k1', 'k2', 'Surface', 'hour', 'round', 'p1_win',
    'p1_age', 'p2_age', 'p1_height', 'p2_height',
    'p1_birthday_today', 'p2_birthday_today', 'overall_winning_serve_prc_player1',
    'overall_winning_serve_prc_player2', 'complete_player1', 'complete_player2',
    'serve_advantage_player1', 'serve_advantage_player2', '1st_match_since_retirement_player1',
            '1st_match_since_retirement_player2'])
# cols2keep = set('k1_1xBet', 'k2_1xBet', 'k1_Betsafe', 'k2_Betsafe', 'k1_Marathonbet', 'k2_Marathonbet',
#              'k1_bet365', 'k2_bet365', 'k1_Betway', 'k2_Betway', 'k1_Pinnacle', 'k2_Pinnacle', 
#               'k1_bet-at-home', 'k2_bet-at-home', 'k1_user', 'k2_user', 'p1_win')
for x in df_new.keys():
    if 'k1' in x or 'k2' in x:
        cols2keep.add(x)
for x in df_new.keys():
    if 'user' in x:
        cols2keep.add(x)
for x in df_new.keys():
    if 'lag' in x:
        cols2keep.add(x)

for stat in df_new.keys():
    if 'common' in stat and 'dif' not in stat:
        cols2keep.add(stat)
# remove_list = ['break_points_prc_match_common_player2', 'Surface', 'break_points_prc_match_common_player1',
#               'hour', 'round']
# for stat in remove_list:
#     cols2keep.remove(stat)
    

data = df_new.loc[df_new.index.get_level_values('date') > features_from, list(cols2keep)] \
    .dropna(subset=['p1_win'])

        

print(data.shape[1])
data.head(3)
# Out:
# 656
#                                       p2_filter_lag_1_max_points_in_a_row_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_lag_1_points_won_match__pctl10_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                   NaN
#            Al Zeyara J. Dustov F.                                      NaN
#            Al-Saygh A.  Bachinger M.                                   NaN
#
#                                       p1_lag_1_second_serve_prc_match__pctl90_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                        NaN
#            Al Zeyara J. Dustov F.                                           NaN
#            Al-Saygh A.  Bachinger M.                                        NaN
#
#                                       p2_lag_1_second_serve_cnt_match__median_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       p2_filter_lag_1_max_points_in_a_row_match__pctl10_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p2_lag_1_first_serve_points_cnt_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                               NaN
#            Al Zeyara J. Dustov F.                                                  NaN
#            Al-Saygh A.  Bachinger M.                                               NaN
#
#                                       p1_lag_1_receiver_points_won_match__pctl10_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                           NaN
#            Al Zeyara J. Dustov F.                                              NaN
#            Al-Saygh A.  Bachinger M.                                           NaN
#
#                                       p1_filter_lag_1_second_serve_points_cnt_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_lag_1_match_dur_pctl90_1  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                          NaN
#            Al Zeyara J. Dustov F.                             NaN
#            Al-Saygh A.  Bachinger M.                          NaN
#
#                                       p1_filter_lag_1_max_points_in_a_row_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p2_lag_1_aces_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                             NaN
#            Al Zeyara J. Dustov F.                                NaN
#            Al-Saygh A.  Bachinger M.                             NaN
#
#                                       p2_filter_lag_1_aces_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                   4.5
#            Al Zeyara J. Dustov F.                                      4.0
#            Al-Saygh A.  Bachinger M.                                   7.0
#
#                                       p1_lag_1_first_serve_prc_match__pctl10_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                        NaN
#            Al Zeyara J. Dustov F.                                           NaN
#            Al-Saygh A.  Bachinger M.                                        NaN
#
#                                       p2_lag_1_match_dur_median_1  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                          6.0
#            Al Zeyara J. Dustov F.                            76.0
#            Al-Saygh A.  Bachinger M.                         85.0
#
#                                       p1_lag_1_second_serve_cnt_match__pctl10_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                        NaN
#            Al Zeyara J. Dustov F.                                           NaN
#            Al-Saygh A.  Bachinger M.                                        NaN
#
#                                       p1_lag_1_first_serve_points_prc_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                            NaN
#            Al Zeyara J. Dustov F.                                               NaN
#            Al-Saygh A.  Bachinger M.                                            NaN
#
#                                       p1_filter_lag_1_break_points_prc_match__median_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_lag_1_second_serve_points_cnt_match__pctl10_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_filter_lag_1_first_serve_points_cnt_match__pctl90_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p2_lag_1_points_won_match__median_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                   NaN
#            Al Zeyara J. Dustov F.                                      NaN
#            Al-Saygh A.  Bachinger M.                                   NaN
#
#                                       p1_filter_lag_1_second_serve_prc_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                              NaN
#            Al Zeyara J. Dustov F.                                                 NaN
#            Al-Saygh A.  Bachinger M.                                              NaN
#
#                                       p1_filter_lag_1_bp_saved_cnt__median_7_y  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                       NaN
#            Al Zeyara J. Dustov F.                                          NaN
#            Al-Saygh A.  Bachinger M.                                       NaN
#
#                                       p2_lag_1_second_serve_points_prc_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                             NaN
#            Al Zeyara J. Dustov F.                                                NaN
#            Al-Saygh A.  Bachinger M.                                             NaN
#
#                                       p1_lag_1_second_serve_cnt_match__median_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       p2_lag_1_break_points_prc_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       ...  \
# date       p1           p2            ...
# 2015-01-03 Adnaoui M.   De Bakker T.  ...
#            Al Zeyara J. Dustov F.     ...
#            Al-Saygh A.  Bachinger M.  ...
#
#                                       p2_filter_lag_1_second_serve_points_cnt_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p2_filter_lag_1_receiver_points_won_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_lag_1_receiver_points_won_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       p2_filter_lag_1_match_dur_median_1  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                 6.0
#            Al Zeyara J. Dustov F.                                   76.0
#            Al-Saygh A.  Bachinger M.                               106.0
#
#                                       p1_lag_1_second_serve_points_cnt_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_filter_lag_1_aces_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                  NaN
#            Al Zeyara J. Dustov F.                                     NaN
#            Al-Saygh A.  Bachinger M.                                  NaN
#
#                                       p1_lag_1_first_serve_cnt_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                     NaN
#            Al Zeyara J. Dustov F.                                        NaN
#            Al-Saygh A.  Bachinger M.                                     NaN
#
#                                       p2_lag_1_bp_saved_cnt__median_28_y  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                 NaN
#            Al Zeyara J. Dustov F.                                    NaN
#            Al-Saygh A.  Bachinger M.                                 NaN
#
#                                       p1_lag_1_first_serve_cnt_match__pctl90_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                       NaN
#            Al Zeyara J. Dustov F.                                          NaN
#            Al-Saygh A.  Bachinger M.                                       NaN
#
#                                       p1_lag_1_aces_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                            NaN
#            Al Zeyara J. Dustov F.                               NaN
#            Al-Saygh A.  Bachinger M.                            NaN
#
#                                       p2_lag_1_break_points_cnt_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       p2_filter_lag_1_break_points_prc_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                              NaN
#            Al Zeyara J. Dustov F.                                                 NaN
#            Al-Saygh A.  Bachinger M.                                              NaN
#
#                                       p1_lag_1_second_serve_prc_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                         NaN
#            Al Zeyara J. Dustov F.                                            NaN
#            Al-Saygh A.  Bachinger M.                                         NaN
#
#                                       p2_filter_lag_1_first_serve_points_prc_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       break_points_prc_match_common_player1  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                    NaN
#            Al Zeyara J. Dustov F.                                       NaN
#            Al-Saygh A.  Bachinger M.                                    NaN
#
#                                       p1_filter_lag_1_points_won_match__pctl90_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                          NaN
#            Al Zeyara J. Dustov F.                                             NaN
#            Al-Saygh A.  Bachinger M.                                          NaN
#
#                                       p1_lag_1_second_serve_points_cnt_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                              NaN
#            Al Zeyara J. Dustov F.                                                 NaN
#            Al-Saygh A.  Bachinger M.                                              NaN
#
#                                       p2_lag_1_first_serve_points_prc_match__mean_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                             NaN
#            Al Zeyara J. Dustov F.                                                NaN
#            Al-Saygh A.  Bachinger M.                                             NaN
#
#                                       p2_filter_lag_1_second_serve_prc_match__mean_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                             NaN
#            Al Zeyara J. Dustov F.                                                NaN
#            Al-Saygh A.  Bachinger M.                                             NaN
#
#                                       p1_filter_lag_1_second_serve_points_prc_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                                NaN
#            Al Zeyara J. Dustov F.                                                   NaN
#            Al-Saygh A.  Bachinger M.                                                NaN
#
#                                       p1_filter_lag_1_first_serve_prc_match__median_7  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                              NaN
#            Al Zeyara J. Dustov F.                                                 NaN
#            Al-Saygh A.  Bachinger M.                                              NaN
#
#                                       p1_filter_lag_1_points_won_match__median_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                          NaN
#            Al Zeyara J. Dustov F.                                             NaN
#            Al-Saygh A.  Bachinger M.                                          NaN
#
#                                       p2_lag_1_receiver_points_won_match__pctl10_28  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                            NaN
#            Al Zeyara J. Dustov F.                                               NaN
#            Al-Saygh A.  Bachinger M.                                            NaN
#
#                                       p2_lag_1_bp_saved_cnt__pctl90_7_x  \
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                NaN
#            Al Zeyara J. Dustov F.                                   NaN
#            Al-Saygh A.  Bachinger M.                                NaN
#
#                                       p1_lag_1_first_serve_cnt_match__pctl10_28
# date       p1           p2
# 2015-01-03 Adnaoui M.   De Bakker T.                                        NaN
#            Al Zeyara J. Dustov F.                                           NaN
#            Al-Saygh A.  Bachinger M.                                        NaN
#
# [3 rows x 656 columns]

# %%
data.to_pickle('all_features.pkl')

# %%
data.to_pickle("final_data_common_lag_ranks.pkl")

# %%
len(data[(data['k1_1xBet'] < 2) & (data['p1_win'] == 1) | (data['k2_1xBet'] < 2) & (data['p1_win'] == 0)]) / len(data)
# Out:
# 0.6820868048827746

# %%
pd.read_pickle('all_coefs_with_Nan.pkl')
# Out:
#                                                  p1_win  k1_1xBet  k2_1xBet  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.           1      1.41      3.12
#            Kamke T.              Mott B.              1      1.11      7.90
#            Kuznetsov Al.         Kubot L.             0      2.32      1.67
#            Uchiyama Y.           Pouille L.           1      4.35      1.25
#            Podlipnik-Castillo H. Reid M.              0      3.20      1.39
# ...                                                 ...       ...       ...
# 2020-11-20 Djokovic N.           Zverev A.            1      1.35      3.30
#            Medvedev D.           Schwartzman D.       1      1.29      3.80
# 2020-11-21 Thiem D.              Djokovic N.          1      2.37      1.66
#            Medvedev D.           Nadal R.             1      1.85      2.16
# 2020-11-22 Medvedev D.           Thiem D.             1      1.71      2.26
#
#                                                  k1_bet-at-home  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.                1.39
#            Kamke T.              Mott B.                   1.06
#            Kuznetsov Al.         Kubot L.                  2.20
#            Uchiyama Y.           Pouille L.                3.68
#            Podlipnik-Castillo H. Reid M.                   2.92
# ...                                                         ...
# 2020-11-20 Djokovic N.           Zverev A.                 1.30
#            Medvedev D.           Schwartzman D.            1.26
# 2020-11-21 Thiem D.              Djokovic N.               2.46
#            Medvedev D.           Nadal R.                  1.77
# 2020-11-22 Medvedev D.           Thiem D.                  1.61
#
#                                                  k2_bet-at-home  k1_Betsafe  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.                2.79        1.29
#            Kamke T.              Mott B.                   7.17        1.07
#            Kuznetsov Al.         Kubot L.                  1.60        1.99
#            Uchiyama Y.           Pouille L.                1.24        3.95
#            Podlipnik-Castillo H. Reid M.                   1.36        2.90
# ...                                                         ...         ...
# 2020-11-20 Djokovic N.           Zverev A.                 3.35        1.30
#            Medvedev D.           Schwartzman D.            3.60        1.28
# 2020-11-21 Thiem D.              Djokovic N.               1.51        2.60
#            Medvedev D.           Nadal R.                  1.98        1.82
# 2020-11-22 Medvedev D.           Thiem D.                  2.22        1.62
#
#                                                  k2_Betsafe  k1_bwin  k2_bwin  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.            3.15     1.40     2.75
#            Kamke T.              Mott B.               6.40     1.11     5.50
#            Kuznetsov Al.         Kubot L.              1.71     2.25     1.57
#            Uchiyama Y.           Pouille L.            1.20     4.10     1.20
#            Podlipnik-Castillo H. Reid M.               1.34     2.75     1.40
# ...                                                     ...      ...      ...
# 2020-11-20 Djokovic N.           Zverev A.             3.60     1.30     3.70
#            Medvedev D.           Schwartzman D.        3.60     1.30     3.70
# 2020-11-21 Thiem D.              Djokovic N.           1.50     2.55     1.55
#            Medvedev D.           Nadal R.              1.98     1.85     2.00
# 2020-11-22 Medvedev D.           Thiem D.              2.30     1.62     2.35
#
#                                                  k1_Marathonbet  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.                1.40
#            Kamke T.              Mott B.                   1.10
#            Kuznetsov Al.         Kubot L.                  2.32
#            Uchiyama Y.           Pouille L.                4.35
#            Podlipnik-Castillo H. Reid M.                   3.20
# ...                                                         ...
# 2020-11-20 Djokovic N.           Zverev A.                 1.34
#            Medvedev D.           Schwartzman D.            1.28
# 2020-11-21 Thiem D.              Djokovic N.               2.57
#            Medvedev D.           Nadal R.                  1.85
# 2020-11-22 Medvedev D.           Thiem D.                  1.72
#
#                                                  k2_Marathonbet  k1_Unibet  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.                3.10       1.37
#            Kamke T.              Mott B.                   7.90       1.09
#            Kuznetsov Al.         Kubot L.                  1.65       2.32
#            Uchiyama Y.           Pouille L.                1.24       4.30
#            Podlipnik-Castillo H. Reid M.                   1.38        NaN
# ...                                                         ...        ...
# 2020-11-20 Djokovic N.           Zverev A.                 3.92       1.32
#            Medvedev D.           Schwartzman D.            3.84       1.33
# 2020-11-21 Thiem D.              Djokovic N.               1.63       2.50
#            Medvedev D.           Nadal R.                  2.16       1.83
# 2020-11-22 Medvedev D.           Thiem D.                  2.38       1.66
#
#                                                  k2_Unibet  k1_888sport  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.           3.00         1.37
#            Kamke T.              Mott B.              7.50         1.09
#            Kuznetsov Al.         Kubot L.             1.58         2.32
#            Uchiyama Y.           Pouille L.           1.20         4.30
#            Podlipnik-Castillo H. Reid M.               NaN         2.75
# ...                                                    ...          ...
# 2020-11-20 Djokovic N.           Zverev A.            3.50         1.32
#            Medvedev D.           Schwartzman D.       3.40         1.33
# 2020-11-21 Thiem D.              Djokovic N.          1.56         2.50
#            Medvedev D.           Nadal R.             2.02         1.83
# 2020-11-22 Medvedev D.           Thiem D.             2.25         1.66
#
#                                                  k2_888sport  k1_bet365  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.             3.00       1.36
#            Kamke T.              Mott B.                7.50       1.07
#            Kuznetsov Al.         Kubot L.               1.58       2.10
#            Uchiyama Y.           Pouille L.             1.20       3.75
#            Podlipnik-Castillo H. Reid M.                1.42       3.00
# ...                                                      ...        ...
# 2020-11-20 Djokovic N.           Zverev A.              3.50       1.33
#            Medvedev D.           Schwartzman D.         3.40       1.25
# 2020-11-21 Thiem D.              Djokovic N.            1.56       2.25
#            Medvedev D.           Nadal R.               2.02       1.75
# 2020-11-22 Medvedev D.           Thiem D.               2.25       1.66
#
#                                                  k2_bet365  k1_Betway  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.           3.00        NaN
#            Kamke T.              Mott B.              7.50        NaN
#            Kuznetsov Al.         Kubot L.             1.66        NaN
#            Uchiyama Y.           Pouille L.           1.25        NaN
#            Podlipnik-Castillo H. Reid M.              1.36        NaN
# ...                                                    ...        ...
# 2020-11-20 Djokovic N.           Zverev A.            3.25       1.29
#            Medvedev D.           Schwartzman D.       3.75       1.29
# 2020-11-21 Thiem D.              Djokovic N.          1.57       2.50
#            Medvedev D.           Nadal R.             2.00       1.80
# 2020-11-22 Medvedev D.           Thiem D.             2.20       1.62
#
#                                                  k2_Betway  k1_bwin.fr  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.            NaN         NaN
#            Kamke T.              Mott B.               NaN         NaN
#            Kuznetsov Al.         Kubot L.              NaN         NaN
#            Uchiyama Y.           Pouille L.            NaN         NaN
#            Podlipnik-Castillo H. Reid M.               NaN         NaN
# ...                                                    ...         ...
# 2020-11-20 Djokovic N.           Zverev A.            3.60        1.26
#            Medvedev D.           Schwartzman D.       3.60        1.26
# 2020-11-21 Thiem D.              Djokovic N.          1.53        2.40
#            Medvedev D.           Nadal R.             2.00        1.78
# 2020-11-22 Medvedev D.           Thiem D.             2.30        1.55
#
#                                                  k2_bwin.fr  k1_Pinnacle  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.             NaN         1.49
#            Kamke T.              Mott B.                NaN         1.07
#            Kuznetsov Al.         Kubot L.               NaN         2.20
#            Uchiyama Y.           Pouille L.             NaN         3.78
#            Podlipnik-Castillo H. Reid M.                NaN         3.08
# ...                                                     ...          ...
# 2020-11-20 Djokovic N.           Zverev A.             3.40         1.32
#            Medvedev D.           Schwartzman D.        3.40         1.30
# 2020-11-21 Thiem D.              Djokovic N.           1.48         2.70
#            Medvedev D.           Nadal R.              1.91         1.88
# 2020-11-22 Medvedev D.           Thiem D.              2.25         1.66
#
#                                                  k2_Pinnacle  k1_user  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.             2.74     1.49
#            Kamke T.              Mott B.                9.20      NaN
#            Kuznetsov Al.         Kubot L.               1.71     3.45
#            Uchiyama Y.           Pouille L.             1.29      NaN
#            Podlipnik-Castillo H. Reid M.                1.40      NaN
# ...                                                      ...      ...
# 2020-11-20 Djokovic N.           Zverev A.              3.78     1.19
#            Medvedev D.           Schwartzman D.         3.96     5.56
# 2020-11-21 Thiem D.              Djokovic N.            1.54     1.28
#            Medvedev D.           Nadal R.               2.04     1.82
# 2020-11-22 Medvedev D.           Thiem D.               2.40     2.50
#
#                                                  k2_user  k1_BetWorld  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.         3.03          NaN
#            Kamke T.              Mott B.             NaN          NaN
#            Kuznetsov Al.         Kubot L.           1.41          NaN
#            Uchiyama Y.           Pouille L.          NaN          NaN
#            Podlipnik-Castillo H. Reid M.             NaN          NaN
# ...                                                  ...          ...
# 2020-11-20 Djokovic N.           Zverev A.          6.25          NaN
#            Medvedev D.           Schwartzman D.     1.22          NaN
# 2020-11-21 Thiem D.              Djokovic N.        4.55          NaN
#            Medvedev D.           Nadal R.           2.22          NaN
# 2020-11-22 Medvedev D.           Thiem D.           1.67          NaN
#
#                                                  k2_BetWorld  k1_Bethard  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.              NaN         NaN
#            Kamke T.              Mott B.                 NaN         NaN
#            Kuznetsov Al.         Kubot L.                NaN         NaN
#            Uchiyama Y.           Pouille L.              NaN         NaN
#            Podlipnik-Castillo H. Reid M.                 NaN         NaN
# ...                                                      ...         ...
# 2020-11-20 Djokovic N.           Zverev A.               NaN        1.33
#            Medvedev D.           Schwartzman D.          NaN        1.30
# 2020-11-21 Thiem D.              Djokovic N.             NaN        2.65
#            Medvedev D.           Nadal R.                NaN        1.87
# 2020-11-22 Medvedev D.           Thiem D.                NaN        1.71
#
#                                                  k2_Bethard  k1_Coolbet  \
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.             NaN         NaN
#            Kamke T.              Mott B.                NaN         NaN
#            Kuznetsov Al.         Kubot L.               NaN         NaN
#            Uchiyama Y.           Pouille L.             NaN         NaN
#            Podlipnik-Castillo H. Reid M.                NaN         NaN
# ...                                                     ...         ...
# 2020-11-20 Djokovic N.           Zverev A.             3.70        1.32
#            Medvedev D.           Schwartzman D.        3.95        1.31
# 2020-11-21 Thiem D.              Djokovic N.           1.56        2.31
#            Medvedev D.           Nadal R.              2.10        1.78
# 2020-11-22 Medvedev D.           Thiem D.              2.35        1.66
#
#                                                  k2_Coolbet
# date       p1                    p2
# 2015-01-03 Ilhan M.              Kovalik J.             NaN
#            Kamke T.              Mott B.                NaN
#            Kuznetsov Al.         Kubot L.               NaN
#            Uchiyama Y.           Pouille L.             NaN
#            Podlipnik-Castillo H. Reid M.                NaN
# ...                                                     ...
# 2020-11-20 Djokovic N.           Zverev A.             3.78
#            Medvedev D.           Schwartzman D.        3.87
# 2020-11-21 Thiem D.              Djokovic N.           1.62
#            Medvedev D.           Nadal R.              2.05
# 2020-11-22 Medvedev D.           Thiem D.              2.40
#
# [22094 rows x 31 columns]

# %%
## lag1
## _mdur(исходная статистика)
## _method
## _window
## _surfacetype(all, surface_name)

# %%
## Информация о players:
## 148 players len(name + surname) > 2
## 1217 players len(name + surname) == 2
## 11 countries, not players
## Идея: сначала сделать fix_name по принципу: берем последнее слово из player1.split() в качестве фамилии, а затем fix_name:
## берем все слова с первого из player1.split() в качестве фамилии
## Итог: Выкинуто 50 игроков и их матчи(почти все малоизвестные)

# %%
## НЕПРИЯТНО: у 6к матчей нет k1 k2(матчи в 2014) - по сути дроп всех матчей 2014 года

# %%
df
