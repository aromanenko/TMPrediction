# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_pickle('final_data.pkl')

print(data.shape)
data.head(1)
# Out:
# (36814, 136)
#                                 Surface  hour  round  player1_win     p1_age  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.      0.0    13    1.0            1  28.065753
#
#                                    p2_age    k1   k2  height_player1  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.  28.317808  1.08  8.0            1.91
#
#                                 height_player2  ...  \
# date       player1   player2                    ...
# 2015-06-01 Murray A. Chardy J.            1.88  ...
#
#                                 lag_max_points_in_a_row_match_player2_pctl90_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_max_points_in_a_row_match_player2_pctl10_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player1_median_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player1_mean_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                            NaN
#
#                                 lag_receiver_points_won_match_player1_pctl90_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player1_pctl10_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player2_median_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player2_mean_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                            NaN
#
#                                 lag_receiver_points_won_match_player2_pctl90_28  \
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
#                                 lag_receiver_points_won_match_player2_pctl10_28
# date       player1   player2
# 2015-06-01 Murray A. Chardy J.                                              NaN
#
# [1 rows x 136 columns]

# %%
y = data['player1_win'].astype(int)
X = data.drop(['player1_win'], axis=1)
## date_idx = X.index.get_level_values('date')

# %%
## some test periods
test_periods = [
    ('2019-01-01', '2019-04-01'),
    ('2019-04-01', '2019-07-01'),
    ('2019-07-01', '2019-10-01'),
    ('2019-10-01', '2020-04-01'),
    ('2020-08-01', '2020-11-01'),
]

for p in test_periods:
    n_test = data[(date_idx >= p[0]) & (date_idx < p[1])].shape[0]
    print('test period: {}, match count: {:,}'.format(p, n_test))
# Out:
# test period: ('2019-01-01', '2019-04-01'), match count: 2,178
# test period: ('2019-04-01', '2019-07-01'), match count: 2,216
# test period: ('2019-07-01', '2019-10-01'), match count: 2,170
# test period: ('2019-10-01', '2020-04-01'), match count: 2,608
# test period: ('2020-08-01', '2020-11-01'), match count: 1,768

# %%
test_from, test_to = test_periods[0]

X_test = X[(date_idx >= test_from) & (date_idx < test_to)]
y_test = y[(date_idx >= test_from) & (date_idx < test_to)]
X_train = X[date_idx < test_from]
y_train = y[date_idx < test_from]

# %%
X_train
# Out:
#                                               Surface  hour  round     p1_age  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.               0.0    13    1.0  28.065753
#            Sock J.        Nadal R.                0.0    17    1.0  22.698630
#            Djokovic N.    Gasquet R.              0.0    18    1.0  28.046575
# 2015-06-02 Nishikori K.   Tsonga J.               0.0    16   25.0  25.441096
#            Wawrinka S.    Federer R.              0.0    17   25.0  30.200000
# ...                                               ...   ...    ...        ...
# 2018-12-31 Darcis S.      Carballés Baena R.      3.0    12    5.0  34.824658
#            Munar J.       Albot R.                3.0    14    5.0  21.671233
#            Donskoy E.     Andújar P.              3.0    14    5.0  28.665753
#            Gunneswaran P. Mmoh M.                 3.0    14    5.0  29.153425
#            Sousa P.       Gulbis E.               3.0    16    5.0  30.616438
#
#                                                  p2_age    k1     k2  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.           28.317808  1.08   8.00
#            Sock J.        Nadal R.            29.013699  9.00   1.07
#            Djokovic N.    Gasquet R.          28.972603  1.00  19.00
# 2015-06-02 Nishikori K.   Tsonga J.           30.145205  1.29   3.75
#            Wawrinka S.    Federer R.          33.838356  2.75   1.44
# ...                                                 ...   ...    ...
# 2018-12-31 Darcis S.      Carballés Baena R.  25.791781  2.37   1.53
#            Munar J.       Albot R.            29.156164  2.00   1.72
#            Donskoy E.     Andújar P.          32.958904  1.50   2.50
#            Gunneswaran P. Mmoh M.             20.986301  2.10   1.66
#            Sousa P.       Gulbis E.           30.356164  3.25   1.33
#
#                                               height_player1  height_player2  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                     1.91            1.88
#            Sock J.        Nadal R.                      1.91            1.85
#            Djokovic N.    Gasquet R.                    1.88            1.83
# 2015-06-02 Nishikori K.   Tsonga J.                     1.78            1.88
#            Wawrinka S.    Federer R.                    1.83            1.85
# ...                                                      ...             ...
# 2018-12-31 Darcis S.      Carballés Baena R.            1.75            1.83
#            Munar J.       Albot R.                      1.83            1.75
#            Donskoy E.     Andújar P.                    1.85            1.80
#            Gunneswaran P. Mmoh M.                       1.88            1.88
#            Sousa P.       Gulbis E.                     1.80            1.91
#
#                                               p1_birthday_today  ...  \
# date       player1        player2                                ...
# 2015-06-01 Murray A.      Chardy J.                       False  ...
#            Sock J.        Nadal R.                        False  ...
#            Djokovic N.    Gasquet R.                      False  ...
# 2015-06-02 Nishikori K.   Tsonga J.                       False  ...
#            Wawrinka S.    Federer R.                      False  ...
# ...                                                         ...  ...
# 2018-12-31 Darcis S.      Carballés Baena R.              False  ...
#            Munar J.       Albot R.                        False  ...
#            Donskoy E.     Andújar P.                      False  ...
#            Gunneswaran P. Mmoh M.                         False  ...
#            Sousa P.       Gulbis E.                       False  ...
#
#                                               lag_max_points_in_a_row_match_player2_pctl90_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
#                                               lag_max_points_in_a_row_match_player2_pctl10_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
#                                               lag_receiver_points_won_match_player1_median_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                             24.0
#            Munar J.       Albot R.                                                       26.0
#            Donskoy E.     Andújar P.                                                     29.0
#            Gunneswaran P. Mmoh M.                                                        26.5
#            Sousa P.       Gulbis E.                                                      21.0
#
#                                               lag_receiver_points_won_match_player1_mean_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                     NaN
#            Sock J.        Nadal R.                                                      NaN
#            Djokovic N.    Gasquet R.                                                    NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                     NaN
#            Wawrinka S.    Federer R.                                                    NaN
# ...                                                                                     ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                      25.260870
#            Munar J.       Albot R.                                                26.266667
#            Donskoy E.     Andújar P.                                              28.333333
#            Gunneswaran P. Mmoh M.                                                 26.166667
#            Sousa P.       Gulbis E.                                               24.230769
#
#                                               lag_receiver_points_won_match_player1_pctl90_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
#                                               lag_receiver_points_won_match_player1_pctl10_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
#                                               lag_receiver_points_won_match_player2_median_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                             27.0
#            Munar J.       Albot R.                                                       28.0
#            Donskoy E.     Andújar P.                                                     31.0
#            Gunneswaran P. Mmoh M.                                                        30.5
#            Sousa P.       Gulbis E.                                                      28.0
#
#                                               lag_receiver_points_won_match_player2_mean_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                     NaN
#            Sock J.        Nadal R.                                                      NaN
#            Djokovic N.    Gasquet R.                                                    NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                     NaN
#            Wawrinka S.    Federer R.                                                    NaN
# ...                                                                                     ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                      27.130435
#            Munar J.       Albot R.                                                28.266667
#            Donskoy E.     Andújar P.                                              33.388889
#            Gunneswaran P. Mmoh M.                                                 30.166667
#            Sousa P.       Gulbis E.                                               25.230769
#
#                                               lag_receiver_points_won_match_player2_pctl90_28  \
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
#                                               lag_receiver_points_won_match_player2_pctl10_28
# date       player1        player2
# 2015-06-01 Murray A.      Chardy J.                                                       NaN
#            Sock J.        Nadal R.                                                        NaN
#            Djokovic N.    Gasquet R.                                                      NaN
# 2015-06-02 Nishikori K.   Tsonga J.                                                       NaN
#            Wawrinka S.    Federer R.                                                      NaN
# ...                                                                                       ...
# 2018-12-31 Darcis S.      Carballés Baena R.                                              NaN
#            Munar J.       Albot R.                                                        NaN
#            Donskoy E.     Andújar P.                                                      NaN
#            Gunneswaran P. Mmoh M.                                                         NaN
#            Sousa P.       Gulbis E.                                                       NaN
#
# [25652 rows x 135 columns]

# %%
## make n periods in X_train
## ML??
